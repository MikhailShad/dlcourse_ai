# %% [markdown]
# # Задание 3.2 - сверточные нейронные сети (CNNs) в PyTorch
#
# Это упражнение мы буде выполнять в Google Colab - https://colab.research.google.com/
# Google Colab позволяет запускать код в notebook в облаке Google, где можно воспользоваться бесплатным GPU!
#
# Авторы курса благодарят компанию Google и надеятся, что праздник не закончится.
#
# Туториал по настройке Google Colab:
# https://medium.com/deep-learning-turkey/google-colab-free-gpu-tutorial-e113627b9f5d
# (Keras инсталлировать не нужно, наш notebook сам установит PyTorch)

# %%
#!g1.1
# Install PyTorch and download data
# %pip install torch torchvision

# !wget -c http: // ufldl.stanford.edu / housenumbers / train_32x32.mat http: // ufldl.stanford.edu / housenumbers / test_32x32.mat
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: torch in /usr/local/lib/python3.8/dist-packages (1.9.1+cu111)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.8/dist-packages (0.10.1+cu111)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch) (3.7.4.3)
# Requirement already satisfied: pillow>=5.3.0 in /kernel/lib/python3.8/site-packages (from torchvision) (9.1.1)
# Requirement already satisfied: numpy in /kernel/fallback/lib/python3.8/site-packages (from torchvision) (1.19.4)
# WARNING: You are using pip version 21.3.1; however, version 22.1.2 is available.
# You should consider upgrading via the '/usr/local/bin/python3 -m pip install --upgrade pip' command.
# --2022-07-05 19:38:23--  http://ufldl.stanford.edu/housenumbers/train_32x32.mat
# Resolving ufldl.stanford.edu (ufldl.stanford.edu)... 171.64.68.10
# Connecting to ufldl.stanford.edu (ufldl.stanford.edu)|171.64.68.10|:80... connected.
# HTTP request sent, awaiting response... 416 Requested Range Not Satisfiable
#
#     The file is already fully retrieved; nothing to do.
#
# --2022-07-05 19:38:25--  http://ufldl.stanford.edu/housenumbers/test_32x32.mat
# Reusing existing connection to ufldl.stanford.edu:80.
# HTTP request sent, awaiting response... 416 Requested Range Not Satisfiable
#
#     The file is already fully retrieved; nothing to do.

# %%
#!g1.1
from collections import namedtuple

import PIL
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.datasets as dset
from torch.utils.data.sampler import SubsetRandomSampler
from torchvision import transforms

# %%
#!g1.1
device = torch.device("cuda:0")  # Let's make sure GPU is available!

# %% [markdown]
# # Загружаем данные

# %%
#!g1.1
# First, lets load the dataset
data_train = dset.SVHN('./',
                       transform=transforms.Compose([
                           transforms.ToTensor(),
                           transforms.Normalize(mean=[0.43, 0.44, 0.47],
                                                std=[0.20, 0.20, 0.20])
                       ])
                       )
data_test = dset.SVHN('./', split='test', transform=transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.43, 0.44, 0.47],
                         std=[0.20, 0.20, 0.20])
]))

# %% [markdown]
# Разделяем данные на training и validation.
#
# На всякий случай для подробностей - https://pytorch.org/tutorials/beginner/data_loading_tutorial.html

# %%
#!g1.1
batch_size = 64

data_size = data_train.data.shape[0]
validation_split = .2
split = int(np.floor(validation_split * data_size))
indices = list(range(data_size))
np.random.shuffle(indices)

train_indices, val_indices = indices[split:], indices[:split]

train_sampler = SubsetRandomSampler(train_indices)
val_sampler = SubsetRandomSampler(val_indices)

train_loader = torch.utils.data.DataLoader(data_train, batch_size=batch_size, sampler=train_sampler, num_workers=4)
val_loader = torch.utils.data.DataLoader(data_train, batch_size=batch_size, sampler=train_sampler, num_workers=4)

# %%
#!g1.1
# We'll use a special helper module to shape it into a flat tensor
class Flattener(nn.Module):
    def forward(self, x):
        batch_size, *_ = x.shape
        return x.view(batch_size, -1)

# %% [markdown]
# Создадим простейшую сеть с новыми слоями:
# Convolutional - `nn.Conv2d`
# MaxPool - `nn.MaxPool2d`

# %%
#!g1.1
nn_model = nn.Sequential(
    nn.Conv2d(3, 64, 3, padding=1),
    nn.ReLU(inplace=True),
    nn.MaxPool2d(4),
    nn.Conv2d(64, 64, 3, padding=1),
    nn.ReLU(inplace=True),
    nn.MaxPool2d(4),
    Flattener(),
    nn.Linear(64 * 2 * 2, 10),
)

nn_model.type(torch.cuda.FloatTensor)
nn_model.to(device)

loss = nn.CrossEntropyLoss().type(torch.cuda.FloatTensor)
optimizer = optim.SGD(nn_model.parameters(), lr=1e-1, weight_decay=1e-4)

# %% [markdown]
# Восстановите функцию `compute_accuracy` из прошлого задания.
# Единственное отличие в новом - она должна передать данные на GPU прежде чем прогонять через модель. Сделайте это так же, как это делает функция `train_model`

# %%
#!g1.1
def train_model(model, train_loader, val_loader, loss, optimizer, num_epochs, scheduler=None):
    loss_history = []
    train_history = []
    val_history = []
    for epoch in range(num_epochs):
        model.train()  # Enter train mode

        loss_accum = 0
        correct_samples = 0
        total_samples = 0
        for i_step, (x, y) in enumerate(train_loader):
            x_gpu = x.to(device)
            y_gpu = y.to(device)
            prediction = model(x_gpu)
            loss_value = loss(prediction, y_gpu)
            optimizer.zero_grad()
            loss_value.backward()
            optimizer.step()

            _, indices = torch.max(prediction, 1)
            correct_samples += torch.sum(indices == y_gpu)
            total_samples += y.shape[0]

            loss_accum += loss_value

        ave_loss = loss_accum / i_step
        train_accuracy = float(correct_samples) / total_samples
        val_accuracy = compute_accuracy(model, val_loader)

        loss_history.append(float(ave_loss))
        train_history.append(train_accuracy)
        val_history.append(val_accuracy)

        print("Average loss: %f, Train accuracy: %f, Val accuracy: %f" % (ave_loss, train_accuracy, val_accuracy))

        if scheduler:
            scheduler.step()

    return loss_history, train_history, val_history


def compute_accuracy(model, loader):
    """
    Computes accuracy on the dataset wrapped in a loader
    
    Returns: accuracy as a float value between 0 and 1
    """
    model.eval()  # Evaluation mode
    # Copy implementation from previous assignment
    # Don't forget to move the data to device before running it through the model!

    overall, correct = 0, 0

    for _, (x, y) in enumerate(loader):
        x_gpu = x.to(device)
        y_gpu = y.to(device)
        prediction = model(x_gpu)
        prediction_indicies = torch.argmax(prediction, 1)
        correct += torch.sum(prediction_indicies == y_gpu)
        overall += y_gpu.shape[0]

    return correct / overall


loss_history, train_history, val_history = train_model(nn_model, train_loader, val_loader, loss, optimizer, 5)
# Out:
# Average loss: 1.398688, Train accuracy: 0.529093, Val accuracy: 0.749804
# Average loss: 0.698759, Train accuracy: 0.785739, Val accuracy: 0.794936
# Average loss: 0.597343, Train accuracy: 0.820479, Val accuracy: 0.820257
# Average loss: 0.545847, Train accuracy: 0.836928, Val accuracy: 0.847900
# Average loss: 0.515896, Train accuracy: 0.848019, Val accuracy: 0.848957

# %% [markdown]
# # Аугментация данных (Data augmentation)
#
# В работе с изображениями одним из особенно важных методов является аугментация данных - то есть, генерация дополнительных данных для тренировки на основе изначальных.
# Таким образом, мы получаем возможность "увеличить" набор данных для тренировки, что ведет к лучшей работе сети.
# Важно, чтобы аугментированные данные были похожи на те, которые могут встретиться в реальной жизни, иначе польза от аугментаций уменьшается и может ухудшить работу сети.
#
# С PyTorch идут несколько таких алгоритмов, называемых `transforms`. Более подробно про них можно прочитать тут -
# https://pytorch.org/tutorials/beginner/data_loading_tutorial.html#transforms
#
# Ниже мы используем следующие алгоритмы генерации:
# - ColorJitter - случайное изменение цвета
# - RandomHorizontalFlip - горизонтальное отражение с вероятностью 50%
# - RandomVerticalFlip - вертикальное отражение с вероятностью 50%
# - RandomRotation - случайный поворот

# %%
#!g1.1
tfs = transforms.Compose([
    transforms.ColorJitter(hue=.50, saturation=.50),
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
    transforms.RandomRotation(50, resample=PIL.Image.BILINEAR),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.43, 0.44, 0.47],
                         std=[0.20, 0.20, 0.20])
])

# Create augmented train dataset
data_aug_train = dset.SVHN('./',
                           transform=tfs
                           )

train_aug_loader = torch.utils.data.DataLoader(data_aug_train, batch_size=batch_size,
                                               sampler=train_sampler)
# Out:
# <ipython-input-9-35cd912b87d3>:5: DeprecationWarning: BILINEAR is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.BILINEAR instead.
#   transforms.RandomRotation(50, resample=PIL.Image.BILINEAR),
# /usr/local/lib/python3.8/dist-packages/torchvision/transforms/transforms.py:1230: UserWarning: Argument resample is deprecated and will be removed since v0.10.0. Please, use interpolation instead
#   warnings.warn(

# %% [markdown]
# Визуализируем результаты агментации (вообще, смотреть на сгенерированные данные всегда очень полезно).

# %%
#!g1.1
# TODO: Visualize some augmented images!
# hint: you can create new datasets and loaders to accomplish this

# Based on the visualizations, should we keep all the augmentations?

tfs = transforms.Compose([
    transforms.ColorJitter(hue=.20, saturation=.20),
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
    transforms.RandomRotation(10, resample=PIL.Image.BILINEAR),
])

data_aug_vis = dset.SVHN('./',
                         transform=tfs
                         )

plt.figure(figsize=(30, 3))

for i, (x, y) in enumerate(data_aug_vis):
    if i == 10:
        break
    plt.subplot(1, 10, i + 1)
    plt.grid(False)
    plt.imshow(x)
    plt.axis('off')
# Out:
# <ipython-input-10-ff97bc50a55e>:10: DeprecationWarning: BILINEAR is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.BILINEAR instead.
#   transforms.RandomRotation(10, resample=PIL.Image.BILINEAR),
# /usr/local/lib/python3.8/dist-packages/torchvision/transforms/transforms.py:1230: UserWarning: Argument resample is deprecated and will be removed since v0.10.0. Please, use interpolation instead
#   warnings.warn(

# %% [markdown]
# Все ли агментации одинаково полезны на этом наборе данных? Могут ли быть среди них те, которые собьют модель с толку?
#
# Выберите из них только корректные

# %%
#!g1.1
tfs = transforms.Compose([
    transforms.ColorJitter(hue=.20, saturation=.20),
    transforms.RandomRotation(10, resample=PIL.Image.BILINEAR),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.43, 0.44, 0.47],
                         std=[0.20, 0.20, 0.20])
])

# create new instances of loaders with the augmentations you chose
data_aug_train = dset.SVHN('./',
                           transform=tfs
                           )
train_aug_loader = torch.utils.data.DataLoader(data_aug_train, batch_size=batch_size, sampler=train_sampler,
                                               num_workers=4)
# Out:
# <ipython-input-27-ec6312984979>:3: DeprecationWarning: BILINEAR is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.BILINEAR instead.
#   transforms.RandomRotation(10, resample=PIL.Image.BILINEAR),
# /usr/local/lib/python3.8/dist-packages/torchvision/transforms/transforms.py:1230: UserWarning: Argument resample is deprecated and will be removed since v0.10.0. Please, use interpolation instead
#   warnings.warn(

# %%
#!g1.1
# Finally, let's train with augmentations!

# Note we shouldn't use augmentations on validation

loss_history, train_history, val_history = train_model(nn_model, train_aug_loader, val_loader, loss, optimizer, 5)
# Out:
# Average loss: 0.626615, Train accuracy: 0.810821, Val accuracy: 0.837662
# Average loss: 0.563805, Train accuracy: 0.829540, Val accuracy: 0.857045
# Average loss: 0.537674, Train accuracy: 0.838020, Val accuracy: 0.819967
# Average loss: 0.522485, Train accuracy: 0.842968, Val accuracy: 0.857284
# Average loss: 0.507883, Train accuracy: 0.846296, Val accuracy: 0.861448

# %% [markdown]
# # LeNet
# Попробуем имплементировать классическую архитектуру сверточной нейронной сети, предложенную Яном ЛеКуном в 1998 году. В свое время она достигла впечатляющих результатов на MNIST, посмотрим как она справится с SVHN?
# Она описана в статье ["Gradient Based Learning Applied to Document Recognition"](http://yann.lecun.com/exdb/publis/pdf/lecun-01a.pdf), попробуйте прочитать ключевые части и имплементировать предложенную архитетуру на PyTorch.
#
# Реализовывать слои и функцию ошибки LeNet, которых нет в PyTorch, **не нужно** - просто возьмите их размеры и переведите в уже известные нам Convolutional, Pooling и Fully Connected layers.
#
# Если в статье не очень понятно, можно просто погуглить LeNet и разобраться в деталях :)

# %%
#!g1.1
# Implement LeNet-like architecture for SVHN task
lenet_model = nn.Sequential(
    nn.Conv2d(3, 6, 5, padding=0),
    nn.MaxPool2d(2),
    nn.Conv2d(6, 16, 5, padding=0),
    nn.MaxPool2d(2),
    nn.Conv2d(16, 120, 5, padding=0),
    Flattener(),
    nn.Linear(120, 84),
    nn.Linear(84, 10)
)

lenet_model.type(torch.cuda.FloatTensor)
lenet_model.to(device)

loss = nn.CrossEntropyLoss().type(torch.cuda.FloatTensor)
optimizer = optim.SGD(lenet_model.parameters(), lr=1e-1, weight_decay=1e-4)

# %%
#!g1.1
# Let's train it!
loss_history, train_history, val_history = train_model(lenet_model, train_aug_loader, val_loader, loss, optimizer, 10)
# Out:
# Average loss: nan, Train accuracy: 0.169078, Val accuracy: 0.067655
# Average loss: nan, Train accuracy: 0.067655, Val accuracy: 0.067655
# Average loss: nan, Train accuracy: 0.067655, Val accuracy: 0.067655
# Average loss: nan, Train accuracy: 0.067655, Val accuracy: 0.067655
# Average loss: nan, Train accuracy: 0.067655, Val accuracy: 0.067655
# Average loss: nan, Train accuracy: 0.067655, Val accuracy: 0.067655
# Average loss: nan, Train accuracy: 0.067655, Val accuracy: 0.067655
# Average loss: nan, Train accuracy: 0.067655, Val accuracy: 0.067655
# Average loss: nan, Train accuracy: 0.067655, Val accuracy: 0.067655
# Average loss: nan, Train accuracy: 0.067655, Val accuracy: 0.067655

# %% [markdown]
# # Подбор гиперпараметров

# %%
#!g1.1
# The key hyperparameters we're going to tune are learning speed, annealing rate and regularization
# We also encourage you to try different optimizers as well

Hyperparams = namedtuple("Hyperparams", ['learning_rate', 'anneal_epochs', 'reg', 'optimizer_func'])
RunResult = namedtuple("RunResult", ['model', 'train_history', 'val_history', 'final_val_accuracy'])

learning_rates = [1e0, 1e-1, 1e-2, 1e-3, 1e-4]
anneal_coeff = 0.2
anneal_epochs = [1, 2, 4]
reg = [1e-3, 1e-4, 1e-5, 1e-7]
optimizer_funcs = [optim.Adadelta, optim.Adam]

batch_size = 64
epoch_num = 5

# Record all the runs here
# Key should be Hyperparams and values should be RunResult
run_record = {}

# Use grid search or random search and record all runs in run_record dictionnary 
# Important: perform search in logarithmic space!

for lr in learning_rates:
    for wd in reg:
        for optimizer_func in optimizer_funcs:
            for anneal_epoch in anneal_epochs:
                print(f"\n{lr}, {wd}, {optimizer_func}, {anneal_coeff}, {anneal_epoch}")
                test_model = nn.Sequential(
                    nn.Conv2d(3, 6, 5, padding=0),
                    nn.MaxPool2d(2),
                    nn.Conv2d(6, 16, 5, padding=0),
                    nn.MaxPool2d(2),
                    nn.Conv2d(16, 120, 5, padding=0),
                    Flattener(),
                    nn.Linear(120, 84),
                    nn.Linear(84, 10)
                )
                test_model.type(torch.cuda.FloatTensor)
                test_model.to(device)
                optimizer = optimizer_func(test_model.parameters(), lr=lr, weight_decay=wd)
                scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=anneal_epoch, gamma=anneal_coeff)
                loss_history, train_history, val_history = train_model(test_model, train_aug_loader, val_loader, loss,
                                                                       optimizer, epoch_num, scheduler=scheduler)
                run_record[Hyperparams(lr, anneal_epoch, wd, optimizer_func)] = RunResult(test_model, train_history,
                                                                                          val_history, val_history[-1])
# Out:
# 1.0, 0.001, <class 'torch.optim.adadelta.Adadelta'>, 0.2, 1
# Average loss: 0.993268, Train accuracy: 0.689895, Val accuracy: 0.758352
# Average loss: 0.634712, Train accuracy: 0.823772, Val accuracy: 0.848719
# Average loss: 0.578806, Train accuracy: 0.840904, Val accuracy: 0.861260
# Average loss: 0.566547, Train accuracy: 0.843975, Val accuracy: 0.862813
# Average loss: 0.563589, Train accuracy: 0.846330, Val accuracy: 0.863222
#
# 1.0, 0.001, <class 'torch.optim.adadelta.Adadelta'>, 0.2, 2
# Average loss: 1.022513, Train accuracy: 0.678838, Val accuracy: 0.784868
# Average loss: 0.764217, Train accuracy: 0.776047, Val accuracy: 0.805327
# Average loss: 0.605972, Train accuracy: 0.830905, Val accuracy: 0.860287
# Average loss: 0.586714, Train accuracy: 0.838532, Val accuracy: 0.858325
# Average loss: 0.548240, Train accuracy: 0.850135, Val accuracy: 0.870457
#
# 1.0, 0.001, <class 'torch.optim.adadelta.Adadelta'>, 0.2, 4
# Average loss: 0.982590, Train accuracy: 0.692728, Val accuracy: 0.786472
# Average loss: 0.747233, Train accuracy: 0.782701, Val accuracy: 0.797853
# Average loss: 0.708535, Train accuracy: 0.797871, Val accuracy: 0.808808
# Average loss: 0.675891, Train accuracy: 0.807477, Val accuracy: 0.833293
# Average loss: 0.565775, Train accuracy: 0.847029, Val accuracy: 0.868870
#
# 1.0, 0.001, <class 'torch.optim.adam.Adam'>, 0.2, 1
# Average loss: 78121376.000000, Train accuracy: 0.380951, Val accuracy: 0.491451
# Average loss: 24868.380859, Train accuracy: 0.579770, Val accuracy: 0.619971
# Average loss: 17491.460938, Train accuracy: 0.606781, Val accuracy: 0.644627
# Average loss: 15595.052734, Train accuracy: 0.617582, Val accuracy: 0.648142
# Average loss: 15153.604492, Train accuracy: 0.619715, Val accuracy: 0.648176
#
# 1.0, 0.001, <class 'torch.optim.adam.Adam'>, 0.2, 2
# Average loss: 110181112.000000, Train accuracy: 0.290039, Val accuracy: 0.460653
# Average loss: 30909.269531, Train accuracy: 0.462273, Val accuracy: 0.513173
# Average loss: 10454.575195, Train accuracy: 0.564379, Val accuracy: 0.611064
# Average loss: 8269.415039, Train accuracy: 0.561837, Val accuracy: 0.603710
# Average loss: 5811.627930, Train accuracy: 0.593472, Val accuracy: 0.635430
#
# 1.0, 0.001, <class 'torch.optim.adam.Adam'>, 0.2, 4
# Average loss: 102999144.000000, Train accuracy: 0.324438, Val accuracy: 0.495427
# Average loss: 646876168192.000000, Train accuracy: 0.414019, Val accuracy: 0.088046
# Average loss: 1170015616.000000, Train accuracy: 0.149149, Val accuracy: 0.134099
# Average loss: 301912576.000000, Train accuracy: 0.186261, Val accuracy: 0.159796
# Average loss: 72125680.000000, Train accuracy: 0.265348, Val accuracy: 0.279767
#
# 1.0, 0.0001, <class 'torch.optim.adadelta.Adadelta'>, 0.2, 1
# Average loss: 0.992982, Train accuracy: 0.688735, Val accuracy: 0.797427
# Average loss: 0.635082, Train accuracy: 0.823448, Val accuracy: 0.850903
# Average loss: 0.583420, Train accuracy: 0.839044, Val accuracy: 0.857967
# Average loss: 0.576801, Train accuracy: 0.841876, Val accuracy: 0.860339
# Average loss: 0.568656, Train accuracy: 0.843821, Val accuracy: 0.860066
#
# 1.0, 0.0001, <class 'torch.optim.adadelta.Adadelta'>, 0.2, 2
# Average loss: 0.979048, Train accuracy: 0.698205, Val accuracy: 0.784988
# Average loss: 0.738087, Train accuracy: 0.787394, Val accuracy: 0.829471
# Average loss: 0.594281, Train accuracy: 0.837457, Val accuracy: 0.859229
# Average loss: 0.570382, Train accuracy: 0.842815, Val accuracy: 0.860066
# Average loss: 0.541390, Train accuracy: 0.851653, Val accuracy: 0.870389
#
# 1.0, 0.0001, <class 'torch.optim.adadelta.Adadelta'>, 0.2, 4
# Average loss: 0.970299, Train accuracy: 0.698802, Val accuracy: 0.805412
# Average loss: 0.744573, Train accuracy: 0.784015, Val accuracy: 0.817988
# Average loss: 0.701724, Train accuracy: 0.799577, Val accuracy: 0.818107
# Average loss: 0.674037, Train accuracy: 0.808091, Val accuracy: 0.826178
# Average loss: 0.560491, Train accuracy: 0.846654, Val accuracy: 0.868153
#
# 1.0, 0.0001, <class 'torch.optim.adam.Adam'>, 0.2, 1
# Average loss: 65945716.000000, Train accuracy: 0.422261, Val accuracy: 0.608999
# Average loss: 18637.650391, Train accuracy: 0.618520, Val accuracy: 0.651862
# Average loss: 12991.088867, Train accuracy: 0.646418, Val accuracy: 0.670938
# Average loss: 11473.419922, Train accuracy: 0.653107, Val accuracy: 0.677763
# Average loss: 11250.506836, Train accuracy: 0.652527, Val accuracy: 0.680579
#
# 1.0, 0.0001, <class 'torch.optim.adam.Adam'>, 0.2, 2
# Average loss: 78056104.000000, Train accuracy: 0.354247, Val accuracy: 0.556991
# Average loss: 22640.267578, Train accuracy: 0.523155, Val accuracy: 0.599171
# Average loss: 8179.708008, Train accuracy: 0.610859, Val accuracy: 0.653397
# Average loss: 6392.670898, Train accuracy: 0.605689, Val accuracy: 0.652578
# Average loss: 4427.927246, Train accuracy: 0.636505, Val accuracy: 0.683991
#
# 1.0, 0.0001, <class 'torch.optim.adam.Adam'>, 0.2, 4
# Average loss: 72481728.000000, Train accuracy: 0.320155, Val accuracy: 0.516790
# Average loss: 15114.875977, Train accuracy: 0.536447, Val accuracy: 0.635259
# Average loss: 7059.699707, Train accuracy: 0.579122, Val accuracy: 0.608709
# Average loss: 80526.312500, Train accuracy: 0.533188, Val accuracy: 0.665614
# Average loss: 1135.415771, Train accuracy: 0.677115, Val accuracy: 0.703785
#
# 1.0, 1e-05, <class 'torch.optim.adadelta.Adadelta'>, 0.2, 1
# Average loss: 0.990488, Train accuracy: 0.692813, Val accuracy: 0.788776
# Average loss: 0.637346, Train accuracy: 0.821878, Val accuracy: 0.850135
# Average loss: 0.589287, Train accuracy: 0.838873, Val accuracy: 0.858922
# Average loss: 0.579135, Train accuracy: 0.841125, Val accuracy: 0.860134
# Average loss: 0.576644, Train accuracy: 0.843634, Val accuracy: 0.859980
#
# 1.0, 1e-05, <class 'torch.optim.adadelta.Adadelta'>, 0.2, 2
# Average loss: 0.977322, Train accuracy: 0.699007, Val accuracy: 0.793980
# Average loss: 0.741478, Train accuracy: 0.786353, Val accuracy: 0.808962
# Average loss: 0.595986, Train accuracy: 0.835597, Val accuracy: 0.859025
# Average loss: 0.576282, Train accuracy: 0.841245, Val accuracy: 0.863325
# Average loss: 0.547347, Train accuracy: 0.851244, Val accuracy: 0.870167
#
# 1.0, 1e-05, <class 'torch.optim.adadelta.Adadelta'>, 0.2, 4
# Average loss: 0.976463, Train accuracy: 0.697676, Val accuracy: 0.803518
# Average loss: 0.740843, Train accuracy: 0.785022, Val accuracy: 0.793980
# Average loss: 0.700858, Train accuracy: 0.798331, Val accuracy: 0.836774
# Average loss: 0.670997, Train accuracy: 0.809678, Val accuracy: 0.829250
# Average loss: 0.559499, Train accuracy: 0.846398, Val accuracy: 0.869604
#
# 1.0, 1e-05, <class 'torch.optim.adam.Adam'>, 0.2, 1
# Average loss: 74992072.000000, Train accuracy: 0.196533, Val accuracy: 0.238747
# Average loss: 16792.181641, Train accuracy: 0.324028, Val accuracy: 0.346210
# Average loss: 10935.410156, Train accuracy: 0.334522, Val accuracy: 0.350920
# Average loss: 9768.623047, Train accuracy: 0.341125, Val accuracy: 0.366567
# Average loss: 9370.260742, Train accuracy: 0.343105, Val accuracy: 0.369501
#
# 1.0, 1e-05, <class 'torch.optim.adam.Adam'>, 0.2, 2
# Average loss: 63668624.000000, Train accuracy: 0.435928, Val accuracy: 0.602959
# Average loss: 314015.906250, Train accuracy: 0.508293, Val accuracy: 0.465055
# Average loss: 12880.825195, Train accuracy: 0.528871, Val accuracy: 0.578337
# Average loss: 6762.886719, Train accuracy: 0.576118, Val accuracy: 0.627018
# Average loss: 4313.459961, Train accuracy: 0.611832, Val accuracy: 0.647971
#
# 1.0, 1e-05, <class 'torch.optim.adam.Adam'>, 0.2, 4
# Average loss: 82081664.000000, Train accuracy: 0.334010, Val accuracy: 0.460004
# Average loss: 23411.566406, Train accuracy: 0.489506, Val accuracy: 0.551889
# Average loss: 514103869440.000000, Train accuracy: 0.455141, Val accuracy: 0.132546
# Average loss: 932449984.000000, Train accuracy: 0.216036, Val accuracy: 0.315770
# Average loss: 180437088.000000, Train accuracy: 0.360151, Val accuracy: 0.392366
#
# 1.0, 1e-07, <class 'torch.optim.adadelta.Adadelta'>, 0.2, 1
# Average loss: 0.992844, Train accuracy: 0.693257, Val accuracy: 0.789987
# Average loss: 0.633117, Train accuracy: 0.823789, Val accuracy: 0.853684
# Average loss: 0.585310, Train accuracy: 0.838924, Val accuracy: 0.860936
# Average loss: 0.571078, Train accuracy: 0.844811, Val accuracy: 0.861260
# Average loss: 0.568452, Train accuracy: 0.843651, Val accuracy: 0.861396
#
# 1.0, 1e-07, <class 'torch.optim.adadelta.Adadelta'>, 0.2, 2
# Average loss: 0.979193, Train accuracy: 0.696635, Val accuracy: 0.798741
# Average loss: 0.743777, Train accuracy: 0.785141, Val accuracy: 0.815104
# Average loss: 0.593687, Train accuracy: 0.835529, Val accuracy: 0.858854
# Average loss: 0.571956, Train accuracy: 0.841313, Val accuracy: 0.859639
# Average loss: 0.541348, Train accuracy: 0.852404, Val accuracy: 0.870935
#
# 1.0, 1e-07, <class 'torch.optim.adadelta.Adadelta'>, 0.2, 4
# Average loss: 0.984027, Train accuracy: 0.696038, Val accuracy: 0.781661
# Average loss: 0.744472, Train accuracy: 0.784357, Val accuracy: 0.808279
# Average loss: 0.697803, Train accuracy: 0.799969, Val accuracy: 0.823704
# Average loss: 0.669628, Train accuracy: 0.811043, Val accuracy: 0.839880
# Average loss: 0.564962, Train accuracy: 0.846688, Val accuracy: 0.868972
#
# 1.0, 1e-07, <class 'torch.optim.adam.Adam'>, 0.2, 1
# Average loss: 133311264.000000, Train accuracy: 0.362676, Val accuracy: 0.544415
# Average loss: 45094.019531, Train accuracy: 0.599358, Val accuracy: 0.639371
# Average loss: 30022.394531, Train accuracy: 0.635873, Val accuracy: 0.660513
# Average loss: 26112.718750, Train accuracy: 0.646009, Val accuracy: 0.670273
# Average loss: 25063.564453, Train accuracy: 0.650582, Val accuracy: 0.668873
#
# 1.0, 1e-07, <class 'torch.optim.adam.Adam'>, 0.2, 2
# Average loss: 79637672.000000, Train accuracy: 0.361789, Val accuracy: 0.486913
# Average loss: 261075.500000, Train accuracy: 0.422585, Val accuracy: 0.441661
# Average loss: 12241.085938, Train accuracy: 0.487356, Val accuracy: 0.553766
# Average loss: 6647.810059, Train accuracy: 0.528632, Val accuracy: 0.566188
# Average loss: 4360.616211, Train accuracy: 0.566614, Val accuracy: 0.587994
#
# 1.0, 1e-07, <class 'torch.optim.adam.Adam'>, 0.2, 4
# Average loss: 83081808.000000, Train accuracy: 0.319797, Val accuracy: 0.473757
# Average loss: 24811.140625, Train accuracy: 0.501433, Val accuracy: 0.558646
# Average loss: 155571814400.000000, Train accuracy: 0.515647, Val accuracy: 0.104426
# Average loss: 446157979648.000000, Train accuracy: 0.131437, Val accuracy: 0.176893
# Average loss: 166029504.000000, Train accuracy: 0.158977, Val accuracy: 0.176586
#
# 0.1, 0.001, <class 'torch.optim.adadelta.Adadelta'>, 0.2, 1
# Average loss: 1.551816, Train accuracy: 0.476931, Val accuracy: 0.735505
# Average loss: 0.875203, Train accuracy: 0.741119, Val accuracy: 0.771952
# Average loss: 0.828060, Train accuracy: 0.757567, Val accuracy: 0.777531
# Average loss: 0.817353, Train accuracy: 0.761100, Val accuracy: 0.778640
# Average loss: 0.815475, Train accuracy: 0.761987, Val accuracy: 0.778760
#
# 0.1, 0.001, <class 'torch.optim.adadelta.Adadelta'>, 0.2, 2
# Average loss: 1.429901, Train accuracy: 0.521636, Val accuracy: 0.747978
# Average loss: 0.830797, Train accuracy: 0.754240, Val accuracy: 0.794680
# Average loss: 0.729307, Train accuracy: 0.791148, Val accuracy: 0.813569
# Average loss: 0.710985, Train accuracy: 0.797034, Val accuracy: 0.820001
# Average loss: 0.694908, Train accuracy: 0.803604, Val accuracy: 0.823550
#
# 0.1, 0.001, <class 'torch.optim.adadelta.Adadelta'>, 0.2, 4
# Average loss: 1.425224, Train accuracy: 0.532113, Val accuracy: 0.753148
# Average loss: 0.810046, Train accuracy: 0.764666, Val accuracy: 0.806982
# Average loss: 0.718812, Train accuracy: 0.795072, Val accuracy: 0.815736
# Average loss: 0.679408, Train accuracy: 0.807050, Val accuracy: 0.825752
# Average loss: 0.626887, Train accuracy: 0.827509, Val accuracy: 0.845186
#
# 0.1, 0.001, <class 'torch.optim.adam.Adam'>, 0.2, 1
# Average loss: 961.724121, Train accuracy: 0.396444, Val accuracy: 0.618367
# Average loss: 1.138853, Train accuracy: 0.650309, Val accuracy: 0.689349
# Average loss: 0.999752, Train accuracy: 0.695082, Val accuracy: 0.723339
# Average loss: 0.963395, Train accuracy: 0.706481, Val accuracy: 0.733253
# Average loss: 0.955977, Train accuracy: 0.710576, Val accuracy: 0.735215
#
# 0.1, 0.001, <class 'torch.optim.adam.Adam'>, 0.2, 2
# Average loss: 628.396179, Train accuracy: 0.454578, Val accuracy: 0.657390
# Average loss: 1.060891, Train accuracy: 0.689759, Val accuracy: 0.727656
# Average loss: 0.768741, Train accuracy: 0.774869, Val accuracy: 0.806880
# Average loss: 0.746492, Train accuracy: 0.783828, Val accuracy: 0.811965
# Average loss: 0.684700, Train accuracy: 0.805924, Val accuracy: 0.825752
#
# 0.1, 0.001, <class 'torch.optim.adam.Adam'>, 0.2, 4
# Average loss: 1040.500610, Train accuracy: 0.366055, Val accuracy: 0.585247
# Average loss: 1.180872, Train accuracy: 0.635413, Val accuracy: 0.720438
# Average loss: 0.935448, Train accuracy: 0.719466, Val accuracy: 0.763011
# Average loss: 0.840407, Train accuracy: 0.752653, Val accuracy: 0.767635
# Average loss: 0.667366, Train accuracy: 0.810702, Val accuracy: 0.824523
#
# 0.1, 0.0001, <class 'torch.optim.adadelta.Adadelta'>, 0.2, 1
# Average loss: 1.414589, Train accuracy: 0.533427, Val accuracy: 0.754786
# Average loss: 0.828981, Train accuracy: 0.755298, Val accuracy: 0.783503
# Average loss: 0.788653, Train accuracy: 0.770075, Val accuracy: 0.789817
# Average loss: 0.783900, Train accuracy: 0.771508, Val accuracy: 0.790636
# Average loss: 0.780550, Train accuracy: 0.771815, Val accuracy: 0.791045
#
# 0.1, 0.0001, <class 'torch.optim.adadelta.Adadelta'>, 0.2, 2
# Average loss: 1.449797, Train accuracy: 0.521363, Val accuracy: 0.739139
# Average loss: 0.847789, Train accuracy: 0.748848, Val accuracy: 0.783043
# Average loss: 0.732451, Train accuracy: 0.790363, Val accuracy: 0.812681
# Average loss: 0.712783, Train accuracy: 0.795806, Val accuracy: 0.820360
# Average loss: 0.690356, Train accuracy: 0.804423, Val accuracy: 0.823192
#
# 0.1, 0.0001, <class 'torch.optim.adadelta.Adadelta'>, 0.2, 4
# Average loss: 1.436949, Train accuracy: 0.524690, Val accuracy: 0.751442
# Average loss: 0.820914, Train accuracy: 0.757687, Val accuracy: 0.799611
# Average loss: 0.733649, Train accuracy: 0.787974, Val accuracy: 0.817066
# Average loss: 0.685114, Train accuracy: 0.804252, Val accuracy: 0.825223
# Average loss: 0.633193, Train accuracy: 0.822766, Val accuracy: 0.844350
#
# 0.1, 0.0001, <class 'torch.optim.adam.Adam'>, 0.2, 1
# Average loss: 444.721588, Train accuracy: 0.445262, Val accuracy: 0.641675
# Average loss: 0.977076, Train accuracy: 0.702778, Val accuracy: 0.746238
# Average loss: 0.878393, Train accuracy: 0.738286, Val accuracy: 0.767311
# Average loss: 0.845359, Train accuracy: 0.751152, Val accuracy: 0.775740
# Average loss: 0.835886, Train accuracy: 0.755230, Val accuracy: 0.777446
#
# 0.1, 0.0001, <class 'torch.optim.adam.Adam'>, 0.2, 2
# Average loss: 1403.299805, Train accuracy: 0.366618, Val accuracy: 0.600604
# Average loss: 1.277017, Train accuracy: 0.620261, Val accuracy: 0.716633
# Average loss: 0.890145, Train accuracy: 0.735044, Val accuracy: 0.767396
# Average loss: 0.872477, Train accuracy: 0.740743, Val accuracy: 0.782172
# Average loss: 0.787181, Train accuracy: 0.771542, Val accuracy: 0.798161
#
# 0.1, 0.0001, <class 'torch.optim.adam.Adam'>, 0.2, 4
# Average loss: 525.690063, Train accuracy: 0.363939, Val accuracy: 0.593813
# Average loss: 1.178129, Train accuracy: 0.646691, Val accuracy: 0.664505
# Average loss: 0.963845, Train accuracy: 0.719210, Val accuracy: 0.703375
# Average loss: 0.914831, Train accuracy: 0.737058, Val accuracy: 0.780347
# Average loss: 0.654341, Train accuracy: 0.814644, Val accuracy: 0.838157
#
# 0.1, 1e-05, <class 'torch.optim.adadelta.Adadelta'>, 0.2, 1
# Average loss: 1.434230, Train accuracy: 0.529724, Val accuracy: 0.762499
# Average loss: 0.815024, Train accuracy: 0.763523, Val accuracy: 0.791369
# Average loss: 0.775581, Train accuracy: 0.778333, Val accuracy: 0.797649
# Average loss: 0.767413, Train accuracy: 0.781251, Val accuracy: 0.799406
# Average loss: 0.766452, Train accuracy: 0.780176, Val accuracy: 0.799696
#
# 0.1, 1e-05, <class 'torch.optim.adadelta.Adadelta'>, 0.2, 2
# Average loss: 1.445406, Train accuracy: 0.523957, Val accuracy: 0.745726
# Average loss: 0.844613, Train accuracy: 0.749701, Val accuracy: 0.799765
# Average loss: 0.722087, Train accuracy: 0.793468, Val accuracy: 0.816794
# Average loss: 0.701324, Train accuracy: 0.799662, Val accuracy: 0.820343
# Average loss: 0.681201, Train accuracy: 0.806863, Val accuracy: 0.826178
#
# 0.1, 1e-05, <class 'torch.optim.adadelta.Adadelta'>, 0.2, 4
# Average loss: 1.369198, Train accuracy: 0.550353, Val accuracy: 0.778965
# Average loss: 0.775608, Train accuracy: 0.773385, Val accuracy: 0.808586
# Average loss: 0.711400, Train accuracy: 0.796642, Val accuracy: 0.827731
# Average loss: 0.677990, Train accuracy: 0.808774, Val accuracy: 0.829693
# Average loss: 0.625699, Train accuracy: 0.825649, Val accuracy: 0.846517
#
# 0.1, 1e-05, <class 'torch.optim.adam.Adam'>, 0.2, 1
# Average loss: 604.551270, Train accuracy: 0.396649, Val accuracy: 0.663993
# Average loss: 1.038592, Train accuracy: 0.681278, Val accuracy: 0.723185
# Average loss: 0.931918, Train accuracy: 0.722571, Val accuracy: 0.745299
# Average loss: 0.899022, Train accuracy: 0.731171, Val accuracy: 0.756714
# Average loss: 0.892051, Train accuracy: 0.735607, Val accuracy: 0.757909
#
# 0.1, 1e-05, <class 'torch.optim.adam.Adam'>, 0.2, 2
# Average loss: 954.160767, Train accuracy: 0.303570, Val accuracy: 0.543170
# Average loss: 1.185586, Train accuracy: 0.635891, Val accuracy: 0.732638
# Average loss: 0.817092, Train accuracy: 0.761185, Val accuracy: 0.794048
# Average loss: 0.786818, Train accuracy: 0.769478, Val accuracy: 0.788929
# Average loss: 0.714006, Train accuracy: 0.796215, Val accuracy: 0.822015
#
# 0.1, 1e-05, <class 'torch.optim.adam.Adam'>, 0.2, 4
# Average loss: 659.413269, Train accuracy: 0.462785, Val accuracy: 0.671314
# Average loss: 1.117110, Train accuracy: 0.674846, Val accuracy: 0.710542
# Average loss: 0.967521, Train accuracy: 0.721104, Val accuracy: 0.772600
# Average loss: 0.897300, Train accuracy: 0.741102, Val accuracy: 0.787445
# Average loss: 0.654917, Train accuracy: 0.816725, Val accuracy: 0.843651
#
# 0.1, 1e-07, <class 'torch.optim.adadelta.Adadelta'>, 0.2, 1
# Average loss: 1.506127, Train accuracy: 0.500307, Val accuracy: 0.713596
# Average loss: 0.923005, Train accuracy: 0.724892, Val accuracy: 0.760451
# Average loss: 0.874003, Train accuracy: 0.741392, Val accuracy: 0.768880
# Average loss: 0.864313, Train accuracy: 0.744378, Val accuracy: 0.769938
# Average loss: 0.861359, Train accuracy: 0.745060, Val accuracy: 0.770262
#
# 0.1, 1e-07, <class 'torch.optim.adadelta.Adadelta'>, 0.2, 2
# Average loss: 1.440376, Train accuracy: 0.526653, Val accuracy: 0.738986
# Average loss: 0.809807, Train accuracy: 0.762721, Val accuracy: 0.806880
# Average loss: 0.698939, Train accuracy: 0.801590, Val accuracy: 0.825990
# Average loss: 0.681443, Train accuracy: 0.806863, Val accuracy: 0.829488
# Average loss: 0.668545, Train accuracy: 0.810719, Val accuracy: 0.832782
#
# 0.1, 1e-07, <class 'torch.optim.adadelta.Adadelta'>, 0.2, 4
# Average loss: 1.491878, Train accuracy: 0.499863, Val accuracy: 0.734737
# Average loss: 0.850182, Train accuracy: 0.747910, Val accuracy: 0.797785
# Average loss: 0.743112, Train accuracy: 0.783572, Val accuracy: 0.816247
# Average loss: 0.687123, Train accuracy: 0.802597, Val accuracy: 0.828328
# Average loss: 0.629285, Train accuracy: 0.823875, Val accuracy: 0.842866
#
# 0.1, 1e-07, <class 'torch.optim.adam.Adam'>, 0.2, 1
# Average loss: 771.198120, Train accuracy: 0.339607, Val accuracy: 0.511603
# Average loss: 1.298507, Train accuracy: 0.585810, Val accuracy: 0.648756
# Average loss: 1.151879, Train accuracy: 0.639081, Val accuracy: 0.676091
# Average loss: 1.107524, Train accuracy: 0.656503, Val accuracy: 0.685100
# Average loss: 1.094334, Train accuracy: 0.660837, Val accuracy: 0.687643
#
# 0.1, 1e-07, <class 'torch.optim.adam.Adam'>, 0.2, 2
# Average loss: 1128.840820, Train accuracy: 0.372965, Val accuracy: 0.581818
# Average loss: 1.235559, Train accuracy: 0.638143, Val accuracy: 0.721138
# Average loss: 0.836104, Train accuracy: 0.753694, Val accuracy: 0.778231
# Average loss: 0.808749, Train accuracy: 0.763744, Val accuracy: 0.797239
# Average loss: 0.729432, Train accuracy: 0.791711, Val accuracy: 0.809763
#
# 0.1, 1e-07, <class 'torch.optim.adam.Adam'>, 0.2, 4
# Average loss: 853.724609, Train accuracy: 0.379808, Val accuracy: 0.564294
# Average loss: 1.240596, Train accuracy: 0.634594, Val accuracy: 0.737501
# Average loss: 9.585711, Train accuracy: 0.594871, Val accuracy: 0.749462
# Average loss: 0.830199, Train accuracy: 0.756151, Val accuracy: 0.785892
# Average loss: 0.694656, Train accuracy: 0.803518, Val accuracy: 0.824898
#
# 0.01, 0.001, <class 'torch.optim.adadelta.Adadelta'>, 0.2, 1
# Average loss: 2.240878, Train accuracy: 0.186960, Val accuracy: 0.197710
# Average loss: 2.185719, Train accuracy: 0.200713, Val accuracy: 0.212367
# Average loss: 2.169999, Train accuracy: 0.211736, Val accuracy: 0.214910
# Average loss: 2.166822, Train accuracy: 0.213715, Val accuracy: 0.215490
# Average loss: 2.165598, Train accuracy: 0.215370, Val accuracy: 0.215575
#
# 0.01, 0.001, <class 'torch.optim.adadelta.Adadelta'>, 0.2, 2
# Average loss: 2.247665, Train accuracy: 0.176791, Val accuracy: 0.196703
# Average loss: 2.138323, Train accuracy: 0.243661, Val accuracy: 0.328755
# Average loss: 1.990131, Train accuracy: 0.329471, Val accuracy: 0.356073
# Average loss: 1.931286, Train accuracy: 0.355885, Val accuracy: 0.381923
# Average loss: 1.896444, Train accuracy: 0.368102, Val accuracy: 0.386820
#
# 0.01, 0.001, <class 'torch.optim.adadelta.Adadelta'>, 0.2, 4
# Average loss: 2.248749, Train accuracy: 0.179043, Val accuracy: 0.191243
# Average loss: 2.163776, Train accuracy: 0.223339, Val accuracy: 0.298638
# Average loss: 1.921757, Train accuracy: 0.361687, Val accuracy: 0.429768
# Average loss: 1.667278, Train accuracy: 0.453486, Val accuracy: 0.509931
# Average loss: 1.538414, Train accuracy: 0.499744, Val accuracy: 0.530526
#
# 0.01, 0.001, <class 'torch.optim.adam.Adam'>, 0.2, 1
# Average loss: 1.238650, Train accuracy: 0.601816, Val accuracy: 0.757124
# Average loss: 0.686940, Train accuracy: 0.806863, Val accuracy: 0.834812
# Average loss: 0.594420, Train accuracy: 0.835580, Val accuracy: 0.857694
# Average loss: 0.570664, Train accuracy: 0.845323, Val accuracy: 0.863325
# Average loss: 0.561439, Train accuracy: 0.845869, Val accuracy: 0.863546
#
# 0.01, 0.001, <class 'torch.optim.adam.Adam'>, 0.2, 2
# Average loss: 1.258096, Train accuracy: 0.597652, Val accuracy: 0.710149
# Average loss: 1.004007, Train accuracy: 0.693820, Val accuracy: 0.676654
# Average loss: 0.689596, Train accuracy: 0.804935, Val accuracy: 0.834027
# Average loss: 0.644003, Train accuracy: 0.818773, Val accuracy: 0.842985
# Average loss: 0.577319, Train accuracy: 0.840801, Val accuracy: 0.862164
#
# 0.01, 0.001, <class 'torch.optim.adam.Adam'>, 0.2, 4
# Average loss: 1.251366, Train accuracy: 0.596560, Val accuracy: 0.735249
# Average loss: 0.989456, Train accuracy: 0.702283, Val accuracy: 0.734771
# Average loss: 0.975421, Train accuracy: 0.706344, Val accuracy: 0.736529
# Average loss: 0.932486, Train accuracy: 0.719653, Val accuracy: 0.757875
# Average loss: 0.648444, Train accuracy: 0.817169, Val accuracy: 0.843600
#
# 0.01, 0.0001, <class 'torch.optim.adadelta.Adadelta'>, 0.2, 1
# Average loss: 2.261555, Train accuracy: 0.184998, Val accuracy: 0.191311
# Average loss: 2.229605, Train accuracy: 0.191533, Val accuracy: 0.192352
# Average loss: 2.224738, Train accuracy: 0.191294, Val accuracy: 0.192591
# Average loss: 2.224030, Train accuracy: 0.192045, Val accuracy: 0.192677
# Average loss: 2.224008, Train accuracy: 0.192045, Val accuracy: 0.192694
#
# 0.01, 0.0001, <class 'torch.optim.adadelta.Adadelta'>, 0.2, 2
# Average loss: 2.250873, Train accuracy: 0.182763, Val accuracy: 0.192148
# Average loss: 2.173415, Train accuracy: 0.219380, Val accuracy: 0.273504
# Average loss: 2.086862, Train accuracy: 0.282087, Val accuracy: 0.301522
# Average loss: 2.043586, Train accuracy: 0.309490, Val accuracy: 0.324421
# Average loss: 2.014934, Train accuracy: 0.323704, Val accuracy: 0.331382
#
# 0.01, 0.0001, <class 'torch.optim.adadelta.Adadelta'>, 0.2, 4
# Average loss: 2.249348, Train accuracy: 0.180954, Val accuracy: 0.196379
# Average loss: 2.179294, Train accuracy: 0.219704, Val accuracy: 0.255844
# Average loss: 1.999233, Train accuracy: 0.323721, Val accuracy: 0.390404
# Average loss: 1.764500, Train accuracy: 0.426663, Val accuracy: 0.495069
# Average loss: 1.614968, Train accuracy: 0.486793, Val accuracy: 0.513889
#
# 0.01, 0.0001, <class 'torch.optim.adam.Adam'>, 0.2, 1
# Average loss: 1.265982, Train accuracy: 0.591765, Val accuracy: 0.731683
# Average loss: 0.703645, Train accuracy: 0.801010, Val accuracy: 0.834334
# Average loss: 0.609103, Train accuracy: 0.830649, Val accuracy: 0.853582
# Average loss: 0.585532, Train accuracy: 0.840187, Val accuracy: 0.859605
# Average loss: 0.576085, Train accuracy: 0.843173, Val accuracy: 0.860304
#
# 0.01, 0.0001, <class 'torch.optim.adam.Adam'>, 0.2, 2
# Average loss: 1.240004, Train accuracy: 0.606491, Val accuracy: 0.745453
# Average loss: 1.002983, Train accuracy: 0.696738, Val accuracy: 0.726734
# Average loss: 0.671208, Train accuracy: 0.809269, Val accuracy: 0.837184
# Average loss: 0.638672, Train accuracy: 0.819558, Val accuracy: 0.841927
# Average loss: 0.579358, Train accuracy: 0.840358, Val accuracy: 0.863529
#
# 0.01, 0.0001, <class 'torch.optim.adam.Adam'>, 0.2, 4
# Average loss: 1.272307, Train accuracy: 0.596287, Val accuracy: 0.738849
# Average loss: 1.029901, Train accuracy: 0.690151, Val accuracy: 0.696072
# Average loss: 0.988954, Train accuracy: 0.702778, Val accuracy: 0.750981
# Average loss: 0.968832, Train accuracy: 0.715848, Val accuracy: 0.742364
# Average loss: 0.644486, Train accuracy: 0.818926, Val accuracy: 0.848821
#
# 0.01, 1e-05, <class 'torch.optim.adadelta.Adadelta'>, 0.2, 1
# Average loss: 2.258749, Train accuracy: 0.176535, Val accuracy: 0.205047
# Average loss: 2.219453, Train accuracy: 0.207061, Val accuracy: 0.213118
# Average loss: 2.213428, Train accuracy: 0.209876, Val accuracy: 0.214893
# Average loss: 2.211700, Train accuracy: 0.211309, Val accuracy: 0.215114
# Average loss: 2.211563, Train accuracy: 0.211890, Val accuracy: 0.215166
#
# 0.01, 1e-05, <class 'torch.optim.adadelta.Adadelta'>, 0.2, 2
# Average loss: 2.241656, Train accuracy: 0.188974, Val accuracy: 0.213169
# Average loss: 2.097340, Train accuracy: 0.264597, Val accuracy: 0.354162
# Average loss: 1.922732, Train accuracy: 0.352472, Val accuracy: 0.377589
# Average loss: 1.860840, Train accuracy: 0.375456, Val accuracy: 0.401904
# Average loss: 1.825407, Train accuracy: 0.390267, Val accuracy: 0.405982
#
# 0.01, 1e-05, <class 'torch.optim.adadelta.Adadelta'>, 0.2, 4
# Average loss: 2.258549, Train accuracy: 0.166758, Val accuracy: 0.216753
# Average loss: 2.176583, Train accuracy: 0.229772, Val accuracy: 0.269341
# Average loss: 1.992256, Train accuracy: 0.320889, Val accuracy: 0.400198
# Average loss: 1.724964, Train accuracy: 0.437344, Val accuracy: 0.496246
# Average loss: 1.570268, Train accuracy: 0.499812, Val accuracy: 0.525629
#
# 0.01, 1e-05, <class 'torch.optim.adam.Adam'>, 0.2, 1
# Average loss: 1.272025, Train accuracy: 0.594513, Val accuracy: 0.693325
# Average loss: 0.697425, Train accuracy: 0.802409, Val accuracy: 0.838191
# Average loss: 0.603606, Train accuracy: 0.833191, Val accuracy: 0.855288
# Average loss: 0.576145, Train accuracy: 0.839999, Val accuracy: 0.860304
# Average loss: 0.566879, Train accuracy: 0.844948, Val accuracy: 0.861192
#
# 0.01, 1e-05, <class 'torch.optim.adam.Adam'>, 0.2, 2
# Average loss: 1.278502, Train accuracy: 0.591748, Val accuracy: 0.704672
# Average loss: 1.033756, Train accuracy: 0.691056, Val accuracy: 0.725028
# Average loss: 0.674503, Train accuracy: 0.810446, Val accuracy: 0.840187
# Average loss: 0.633486, Train accuracy: 0.820752, Val accuracy: 0.843207
# Average loss: 0.571427, Train accuracy: 0.843634, Val accuracy: 0.865748
#
# 0.01, 1e-05, <class 'torch.optim.adam.Adam'>, 0.2, 4
# Average loss: 1.259726, Train accuracy: 0.601867, Val accuracy: 0.713511
# Average loss: 1.017988, Train accuracy: 0.695065, Val accuracy: 0.721001
# Average loss: 1.049800, Train accuracy: 0.690254, Val accuracy: 0.700287
# Average loss: 0.994784, Train accuracy: 0.707590, Val accuracy: 0.747534
# Average loss: 0.661882, Train accuracy: 0.814098, Val accuracy: 0.847166
#
# 0.01, 1e-07, <class 'torch.optim.adadelta.Adadelta'>, 0.2, 1
# Average loss: 2.264042, Train accuracy: 0.165358, Val accuracy: 0.190049
# Average loss: 2.227419, Train accuracy: 0.190168, Val accuracy: 0.190373
# Average loss: 2.222861, Train accuracy: 0.190629, Val accuracy: 0.190475
# Average loss: 2.222079, Train accuracy: 0.190748, Val accuracy: 0.190509
# Average loss: 2.221933, Train accuracy: 0.190441, Val accuracy: 0.190509
#
# 0.01, 1e-07, <class 'torch.optim.adadelta.Adadelta'>, 0.2, 2
# Average loss: 2.253589, Train accuracy: 0.181261, Val accuracy: 0.191243
# Average loss: 2.190975, Train accuracy: 0.211753, Val accuracy: 0.264359
# Average loss: 2.108088, Train accuracy: 0.270604, Val accuracy: 0.296113
# Average loss: 2.056772, Train accuracy: 0.300874, Val accuracy: 0.322254
# Average loss: 2.021182, Train accuracy: 0.318176, Val accuracy: 0.329761
#
# 0.01, 1e-07, <class 'torch.optim.adadelta.Adadelta'>, 0.2, 4
# Average loss: 2.255352, Train accuracy: 0.184589, Val accuracy: 0.205730
# Average loss: 2.183722, Train accuracy: 0.225233, Val accuracy: 0.257021
# Average loss: 2.010743, Train accuracy: 0.305788, Val accuracy: 0.380883
# Average loss: 1.750781, Train accuracy: 0.420076, Val accuracy: 0.487339
# Average loss: 1.603430, Train accuracy: 0.481231, Val accuracy: 0.509333
#
# 0.01, 1e-07, <class 'torch.optim.adam.Adam'>, 0.2, 1
# Average loss: 1.258502, Train accuracy: 0.602652, Val accuracy: 0.690919
# Average loss: 0.698427, Train accuracy: 0.799833, Val accuracy: 0.835512
# Average loss: 0.608926, Train accuracy: 0.832338, Val accuracy: 0.852865
# Average loss: 0.586741, Train accuracy: 0.839743, Val accuracy: 0.857779
# Average loss: 0.576667, Train accuracy: 0.841535, Val accuracy: 0.858820
#
# 0.01, 1e-07, <class 'torch.optim.adam.Adam'>, 0.2, 2
# Average loss: 1.234994, Train accuracy: 0.615261, Val accuracy: 0.717537
# Average loss: 1.013173, Train accuracy: 0.695748, Val accuracy: 0.706105
# Average loss: 0.677182, Train accuracy: 0.808467, Val accuracy: 0.834539
# Average loss: 0.634091, Train accuracy: 0.820872, Val accuracy: 0.839078
# Average loss: 0.571910, Train accuracy: 0.841876, Val accuracy: 0.862761
#
# 0.01, 1e-07, <class 'torch.optim.adam.Adam'>, 0.2, 4
# Average loss: 1.249963, Train accuracy: 0.601235, Val accuracy: 0.694349
# Average loss: 1.041198, Train accuracy: 0.687592, Val accuracy: 0.713391
# Average loss: 1.032810, Train accuracy: 0.694792, Val accuracy: 0.764137
# Average loss: 1.028247, Train accuracy: 0.700730, Val accuracy: 0.767106
# Average loss: 0.656154, Train accuracy: 0.816299, Val accuracy: 0.845050
#
# 0.001, 0.001, <class 'torch.optim.adadelta.Adadelta'>, 0.2, 1
# Average loss: 2.302746, Train accuracy: 0.120210, Val accuracy: 0.134304
# Average loss: 2.295167, Train accuracy: 0.136573, Val accuracy: 0.138177
# Average loss: 2.293597, Train accuracy: 0.138450, Val accuracy: 0.139184
# Average loss: 2.293221, Train accuracy: 0.137989, Val accuracy: 0.139320
# Average loss: 2.293271, Train accuracy: 0.138501, Val accuracy: 0.139337
#
# 0.001, 0.001, <class 'torch.optim.adadelta.Adadelta'>, 0.2, 2
# Average loss: 2.302027, Train accuracy: 0.095587, Val accuracy: 0.109682
# Average loss: 2.285542, Train accuracy: 0.140429, Val accuracy: 0.156179
# Average loss: 2.276377, Train accuracy: 0.161775, Val accuracy: 0.163601
# Average loss: 2.273308, Train accuracy: 0.167799, Val accuracy: 0.169283
# Average loss: 2.271636, Train accuracy: 0.171808, Val accuracy: 0.170409
#
# 0.001, 0.001, <class 'torch.optim.adadelta.Adadelta'>, 0.2, 4
# Average loss: 2.316403, Train accuracy: 0.069600, Val accuracy: 0.071460
# Average loss: 2.303899, Train accuracy: 0.083097, Val accuracy: 0.108129
# Average loss: 2.289900, Train accuracy: 0.156434, Val accuracy: 0.190271
# Average loss: 2.274816, Train accuracy: 0.193803, Val accuracy: 0.194110
# Average loss: 2.265929, Train accuracy: 0.193410, Val accuracy: 0.193393
#
# 0.001, 0.001, <class 'torch.optim.adam.Adam'>, 0.2, 1
# Average loss: 0.956103, Train accuracy: 0.705406, Val accuracy: 0.811504
# Average loss: 0.640839, Train accuracy: 0.820257, Val accuracy: 0.845750
# Average loss: 0.605292, Train accuracy: 0.831792, Val accuracy: 0.851363
# Average loss: 0.595554, Train accuracy: 0.834932, Val accuracy: 0.852438
# Average loss: 0.593288, Train accuracy: 0.835051, Val accuracy: 0.852899
#
# 0.001, 0.001, <class 'torch.optim.adam.Adam'>, 0.2, 2
# Average loss: 0.997409, Train accuracy: 0.688479, Val accuracy: 0.815736
# Average loss: 0.698102, Train accuracy: 0.801386, Val accuracy: 0.825137
# Average loss: 0.597023, Train accuracy: 0.835614, Val accuracy: 0.858462
# Average loss: 0.584704, Train accuracy: 0.839829, Val accuracy: 0.862983
# Average loss: 0.564742, Train accuracy: 0.845903, Val accuracy: 0.865628
#
# 0.001, 0.001, <class 'torch.optim.adam.Adam'>, 0.2, 4
# Average loss: 1.003017, Train accuracy: 0.686500, Val accuracy: 0.809422
# Average loss: 0.699626, Train accuracy: 0.802443, Val accuracy: 0.832014
# Average loss: 0.668973, Train accuracy: 0.809900, Val accuracy: 0.839777
# Average loss: 0.650173, Train accuracy: 0.818005, Val accuracy: 0.846944
# Average loss: 0.567629, Train accuracy: 0.843907, Val accuracy: 0.865031
#
# 0.001, 0.0001, <class 'torch.optim.adadelta.Adadelta'>, 0.2, 1
# Average loss: 2.309017, Train accuracy: 0.115108, Val accuracy: 0.132341
# Average loss: 2.301000, Train accuracy: 0.134406, Val accuracy: 0.137836
# Average loss: 2.299403, Train accuracy: 0.138126, Val accuracy: 0.139167
# Average loss: 2.299188, Train accuracy: 0.138706, Val accuracy: 0.139354
# Average loss: 2.298989, Train accuracy: 0.139644, Val accuracy: 0.139354
#
# 0.001, 0.0001, <class 'torch.optim.adadelta.Adadelta'>, 0.2, 2
# Average loss: 2.314590, Train accuracy: 0.081698, Val accuracy: 0.090963
# Average loss: 2.295119, Train accuracy: 0.129850, Val accuracy: 0.163260
# Average loss: 2.283173, Train accuracy: 0.169010, Val accuracy: 0.171962
# Average loss: 2.279156, Train accuracy: 0.178736, Val accuracy: 0.179265
# Average loss: 2.276797, Train accuracy: 0.182285, Val accuracy: 0.179999
#
# 0.001, 0.0001, <class 'torch.optim.adadelta.Adadelta'>, 0.2, 4
# Average loss: 2.304487, Train accuracy: 0.129441, Val accuracy: 0.138569
# Average loss: 2.294331, Train accuracy: 0.145872, Val accuracy: 0.153602
# Average loss: 2.283246, Train accuracy: 0.161468, Val accuracy: 0.171552
# Average loss: 2.271248, Train accuracy: 0.178855, Val accuracy: 0.185527
# Average loss: 2.263490, Train accuracy: 0.185169, Val accuracy: 0.187916
#
# 0.001, 0.0001, <class 'torch.optim.adam.Adam'>, 0.2, 1
# Average loss: 0.995432, Train accuracy: 0.691004, Val accuracy: 0.824182
# Average loss: 0.640008, Train accuracy: 0.821947, Val accuracy: 0.845818
# Average loss: 0.607074, Train accuracy: 0.833771, Val accuracy: 0.852541
# Average loss: 0.598443, Train accuracy: 0.836041, Val accuracy: 0.852592
# Average loss: 0.596041, Train accuracy: 0.836621, Val accuracy: 0.852592
#
# 0.001, 0.0001, <class 'torch.optim.adam.Adam'>, 0.2, 2
# Average loss: 1.002006, Train accuracy: 0.686551, Val accuracy: 0.811896
# Average loss: 0.700125, Train accuracy: 0.798502, Val accuracy: 0.822203
# Average loss: 0.597861, Train accuracy: 0.833754, Val accuracy: 0.857933
# Average loss: 0.581820, Train accuracy: 0.838856, Val accuracy: 0.861669
# Average loss: 0.558538, Train accuracy: 0.847541, Val accuracy: 0.864911
#
# 0.001, 0.0001, <class 'torch.optim.adam.Adam'>, 0.2, 4
# Average loss: 0.973007, Train accuracy: 0.698939, Val accuracy: 0.811384
# Average loss: 0.688474, Train accuracy: 0.803365, Val accuracy: 0.808160
# Average loss: 0.655341, Train accuracy: 0.814848, Val accuracy: 0.838771
# Average loss: 0.634220, Train accuracy: 0.821042, Val accuracy: 0.850954
# Average loss: 0.556529, Train accuracy: 0.848616, Val accuracy: 0.868734
#
# 0.001, 1e-05, <class 'torch.optim.adadelta.Adadelta'>, 0.2, 1
# Average loss: 2.292260, Train accuracy: 0.138569, Val accuracy: 0.171996
# Average loss: 2.285372, Train accuracy: 0.171911, Val accuracy: 0.177763
# Average loss: 2.284122, Train accuracy: 0.175255, Val accuracy: 0.178804
# Average loss: 2.283865, Train accuracy: 0.175665, Val accuracy: 0.178855
# Average loss: 2.283643, Train accuracy: 0.176450, Val accuracy: 0.178890
#
# 0.001, 1e-05, <class 'torch.optim.adadelta.Adadelta'>, 0.2, 2
# Average loss: 2.303016, Train accuracy: 0.102925, Val accuracy: 0.138518
# Average loss: 2.289295, Train accuracy: 0.163925, Val accuracy: 0.180476
# Average loss: 2.281429, Train accuracy: 0.182541, Val accuracy: 0.183872
# Average loss: 2.278922, Train accuracy: 0.184947, Val accuracy: 0.185612
# Average loss: 2.277388, Train accuracy: 0.185288, Val accuracy: 0.186022
#
# 0.001, 1e-05, <class 'torch.optim.adadelta.Adadelta'>, 0.2, 4
# Average loss: 2.297328, Train accuracy: 0.125567, Val accuracy: 0.134543
# Average loss: 2.282833, Train accuracy: 0.156127, Val accuracy: 0.169266
# Average loss: 2.268825, Train accuracy: 0.180067, Val accuracy: 0.185920
# Average loss: 2.255883, Train accuracy: 0.188701, Val accuracy: 0.189503
# Average loss: 2.249089, Train accuracy: 0.189810, Val accuracy: 0.189776
#
# 0.001, 1e-05, <class 'torch.optim.adam.Adam'>, 0.2, 1
# Average loss: 0.993529, Train accuracy: 0.688803, Val accuracy: 0.812767
# Average loss: 0.651218, Train accuracy: 0.818176, Val accuracy: 0.844043
# Average loss: 0.614338, Train accuracy: 0.828772, Val accuracy: 0.848241
# Average loss: 0.607542, Train accuracy: 0.832304, Val accuracy: 0.849060
# Average loss: 0.605892, Train accuracy: 0.832150, Val accuracy: 0.849265
#
# 0.001, 1e-05, <class 'torch.optim.adam.Adam'>, 0.2, 2
# Average loss: 0.976683, Train accuracy: 0.697522, Val accuracy: 0.810071
# Average loss: 0.701585, Train accuracy: 0.800225, Val accuracy: 0.825632
# Average loss: 0.607371, Train accuracy: 0.833242, Val accuracy: 0.856926
# Average loss: 0.586018, Train accuracy: 0.837201, Val accuracy: 0.859059
# Average loss: 0.565696, Train accuracy: 0.844913, Val accuracy: 0.863956
#
# 0.001, 1e-05, <class 'torch.optim.adam.Adam'>, 0.2, 4
# Average loss: 0.940855, Train accuracy: 0.710371, Val accuracy: 0.816282
# Average loss: 0.690334, Train accuracy: 0.802955, Val accuracy: 0.839522
# Average loss: 0.655051, Train accuracy: 0.814831, Val accuracy: 0.838839
# Average loss: 0.632714, Train accuracy: 0.821230, Val accuracy: 0.844709
# Average loss: 0.559244, Train accuracy: 0.846944, Val accuracy: 0.868017
#
# 0.001, 1e-07, <class 'torch.optim.adadelta.Adadelta'>, 0.2, 1
# Average loss: 2.301821, Train accuracy: 0.102908, Val accuracy: 0.130396
# Average loss: 2.290064, Train accuracy: 0.141300, Val accuracy: 0.142869
# Average loss: 2.287619, Train accuracy: 0.148978, Val accuracy: 0.145412
# Average loss: 2.287157, Train accuracy: 0.149353, Val accuracy: 0.145838
# Average loss: 2.286914, Train accuracy: 0.150479, Val accuracy: 0.145890
#
# 0.001, 1e-07, <class 'torch.optim.adadelta.Adadelta'>, 0.2, 2
# Average loss: 2.300495, Train accuracy: 0.102839, Val accuracy: 0.135242
# Average loss: 2.285872, Train accuracy: 0.163243, Val accuracy: 0.178651
# Average loss: 2.277646, Train accuracy: 0.182217, Val accuracy: 0.182899
# Average loss: 2.274826, Train accuracy: 0.185920, Val accuracy: 0.185937
# Average loss: 2.273144, Train accuracy: 0.187097, Val accuracy: 0.186500
#
# 0.001, 1e-07, <class 'torch.optim.adadelta.Adadelta'>, 0.2, 4
# Average loss: 2.291643, Train accuracy: 0.178053, Val accuracy: 0.188104
# Average loss: 2.279234, Train accuracy: 0.189008, Val accuracy: 0.189059
# Average loss: 2.267994, Train accuracy: 0.189656, Val accuracy: 0.189571
# Average loss: 2.257626, Train accuracy: 0.190032, Val accuracy: 0.190015
# Average loss: 2.252035, Train accuracy: 0.190151, Val accuracy: 0.190049
#
# 0.001, 1e-07, <class 'torch.optim.adam.Adam'>, 0.2, 1
# Average loss: 0.956784, Train accuracy: 0.703102, Val accuracy: 0.811077
# Average loss: 0.631578, Train accuracy: 0.823585, Val accuracy: 0.848224
# Average loss: 0.599538, Train accuracy: 0.832611, Val accuracy: 0.853752
# Average loss: 0.585844, Train accuracy: 0.838703, Val accuracy: 0.854912
# Average loss: 0.586762, Train accuracy: 0.838941, Val accuracy: 0.854725
#
# 0.001, 1e-07, <class 'torch.optim.adam.Adam'>, 0.2, 2
# Average loss: 0.973524, Train accuracy: 0.697966, Val accuracy: 0.810907
# Average loss: 0.701780, Train accuracy: 0.799679, Val accuracy: 0.832048
# Average loss: 0.594839, Train accuracy: 0.834693, Val accuracy: 0.858752
# Average loss: 0.579211, Train accuracy: 0.840904, Val accuracy: 0.860594
# Average loss: 0.556230, Train accuracy: 0.847831, Val accuracy: 0.866277
#
# 0.001, 1e-07, <class 'torch.optim.adam.Adam'>, 0.2, 4
# Average loss: 0.966339, Train accuracy: 0.701515, Val accuracy: 0.801556
# Average loss: 0.701418, Train accuracy: 0.800174, Val accuracy: 0.834249
# Average loss: 0.659510, Train accuracy: 0.814029, Val accuracy: 0.840494
# Average loss: 0.636496, Train accuracy: 0.820820, Val accuracy: 0.847166
# Average loss: 0.555397, Train accuracy: 0.846893, Val accuracy: 0.867949
#
# 0.0001, 0.001, <class 'torch.optim.adadelta.Adadelta'>, 0.2, 1
# Average loss: 2.301565, Train accuracy: 0.097840, Val accuracy: 0.094649
# Average loss: 2.300904, Train accuracy: 0.099171, Val accuracy: 0.095741
# Average loss: 2.300832, Train accuracy: 0.099887, Val accuracy: 0.095860
# Average loss: 2.300733, Train accuracy: 0.100553, Val accuracy: 0.095860
# Average loss: 2.300783, Train accuracy: 0.099427, Val accuracy: 0.095878
#
# 0.0001, 0.001, <class 'torch.optim.adadelta.Adadelta'>, 0.2, 2
# Average loss: 2.310305, Train accuracy: 0.083780, Val accuracy: 0.086100
# Average loss: 2.308635, Train accuracy: 0.085298, Val accuracy: 0.087551
# Average loss: 2.307657, Train accuracy: 0.085350, Val accuracy: 0.087875
# Average loss: 2.307319, Train accuracy: 0.085742, Val accuracy: 0.088182
# Average loss: 2.307061, Train accuracy: 0.086578, Val accuracy: 0.088284
#
# 0.0001, 0.001, <class 'torch.optim.adadelta.Adadelta'>, 0.2, 4
# Average loss: 2.313243, Train accuracy: 0.073764, Val accuracy: 0.074753
# Average loss: 2.310560, Train accuracy: 0.075709, Val accuracy: 0.076187
# Average loss: 2.308008, Train accuracy: 0.077842, Val accuracy: 0.078968
# Average loss: 2.305382, Train accuracy: 0.081527, Val accuracy: 0.082295
# Average loss: 2.303963, Train accuracy: 0.082910, Val accuracy: 0.083029
#
# 0.0001, 0.001, <class 'torch.optim.adam.Adam'>, 0.2, 1
# Average loss: 1.793405, Train accuracy: 0.384705, Val accuracy: 0.668276
# Average loss: 1.081499, Train accuracy: 0.673549, Val accuracy: 0.709876
# Average loss: 1.026371, Train accuracy: 0.692813, Val accuracy: 0.716189
# Average loss: 1.016508, Train accuracy: 0.695219, Val accuracy: 0.717247
# Average loss: 1.017477, Train accuracy: 0.694929, Val accuracy: 0.717640
#
# 0.0001, 0.001, <class 'torch.optim.adam.Adam'>, 0.2, 2
# Average loss: 1.714704, Train accuracy: 0.418097, Val accuracy: 0.690441
# Average loss: 0.937996, Train accuracy: 0.718988, Val accuracy: 0.777702
# Average loss: 0.810803, Train accuracy: 0.764273, Val accuracy: 0.789731
# Average loss: 0.786581, Train accuracy: 0.773829, Val accuracy: 0.794748
# Average loss: 0.770769, Train accuracy: 0.777361, Val accuracy: 0.796608
#
# 0.0001, 0.001, <class 'torch.optim.adam.Adam'>, 0.2, 4
# Average loss: 1.856046, Train accuracy: 0.369501, Val accuracy: 0.636744
# Average loss: 1.016004, Train accuracy: 0.695117, Val accuracy: 0.770228
# Average loss: 0.809332, Train accuracy: 0.765843, Val accuracy: 0.801744
# Average loss: 0.736196, Train accuracy: 0.789202, Val accuracy: 0.819745
# Average loss: 0.688588, Train accuracy: 0.805208, Val accuracy: 0.825308
#
# 0.0001, 0.0001, <class 'torch.optim.adadelta.Adadelta'>, 0.2, 1
# Average loss: 2.307604, Train accuracy: 0.100126, Val accuracy: 0.099137
# Average loss: 2.306741, Train accuracy: 0.100536, Val accuracy: 0.099239
# Average loss: 2.306632, Train accuracy: 0.099956, Val accuracy: 0.099239
# Average loss: 2.306606, Train accuracy: 0.100280, Val accuracy: 0.099222
# Average loss: 2.306593, Train accuracy: 0.099870, Val accuracy: 0.099222
#
# 0.0001, 0.0001, <class 'torch.optim.adadelta.Adadelta'>, 0.2, 2
# Average loss: 2.303520, Train accuracy: 0.141470, Val accuracy: 0.140549
# Average loss: 2.301550, Train accuracy: 0.144405, Val accuracy: 0.143620
# Average loss: 2.300395, Train accuracy: 0.146163, Val accuracy: 0.144524
# Average loss: 2.299918, Train accuracy: 0.146811, Val accuracy: 0.145292
# Average loss: 2.299697, Train accuracy: 0.146350, Val accuracy: 0.145548
#
# 0.0001, 0.0001, <class 'torch.optim.adadelta.Adadelta'>, 0.2, 4
# Average loss: 2.315883, Train accuracy: 0.077211, Val accuracy: 0.077688
# Average loss: 2.313423, Train accuracy: 0.077688, Val accuracy: 0.079343
# Average loss: 2.311083, Train accuracy: 0.080060, Val accuracy: 0.081630
# Average loss: 2.309026, Train accuracy: 0.083848, Val accuracy: 0.086083
# Average loss: 2.307787, Train accuracy: 0.086288, Val accuracy: 0.087022
#
# 0.0001, 0.0001, <class 'torch.optim.adam.Adam'>, 0.2, 1
# Average loss: 1.913884, Train accuracy: 0.339061, Val accuracy: 0.598335
# Average loss: 1.240949, Train accuracy: 0.613111, Val accuracy: 0.661007
# Average loss: 1.169972, Train accuracy: 0.636931, Val accuracy: 0.666109
# Average loss: 1.158560, Train accuracy: 0.643313, Val accuracy: 0.669010
# Average loss: 1.155601, Train accuracy: 0.644354, Val accuracy: 0.669129
#
# 0.0001, 0.0001, <class 'torch.optim.adam.Adam'>, 0.2, 2
# Average loss: 1.842316, Train accuracy: 0.363188, Val accuracy: 0.626113
# Average loss: 1.061226, Train accuracy: 0.672593, Val accuracy: 0.739412
# Average loss: 0.899595, Train accuracy: 0.731973, Val accuracy: 0.758284
# Average loss: 0.873655, Train accuracy: 0.741153, Val accuracy: 0.765417
# Average loss: 0.855661, Train accuracy: 0.746357, Val accuracy: 0.768607
#
# 0.0001, 0.0001, <class 'torch.optim.adam.Adam'>, 0.2, 4
# Average loss: 1.779678, Train accuracy: 0.397792, Val accuracy: 0.672047
# Average loss: 0.976707, Train accuracy: 0.705184, Val accuracy: 0.767174
# Average loss: 0.807637, Train accuracy: 0.761936, Val accuracy: 0.803621
# Average loss: 0.737366, Train accuracy: 0.787786, Val accuracy: 0.813978
# Average loss: 0.694955, Train accuracy: 0.802802, Val accuracy: 0.824131
#
# 0.0001, 1e-05, <class 'torch.optim.adadelta.Adadelta'>, 0.2, 1
# Average loss: 2.317380, Train accuracy: 0.073764, Val accuracy: 0.073798
# Average loss: 2.316679, Train accuracy: 0.073883, Val accuracy: 0.073832
# Average loss: 2.316649, Train accuracy: 0.074242, Val accuracy: 0.073832
# Average loss: 2.316428, Train accuracy: 0.074156, Val accuracy: 0.073832
# Average loss: 2.316523, Train accuracy: 0.073849, Val accuracy: 0.073832
#
# 0.0001, 1e-05, <class 'torch.optim.adadelta.Adadelta'>, 0.2, 2
# Average loss: 2.303343, Train accuracy: 0.126967, Val accuracy: 0.135430
# Average loss: 2.301976, Train accuracy: 0.139235, Val accuracy: 0.148244
# Average loss: 2.301123, Train accuracy: 0.148364, Val accuracy: 0.150565
# Average loss: 2.300942, Train accuracy: 0.150974, Val accuracy: 0.153636
# Average loss: 2.300633, Train accuracy: 0.150292, Val accuracy: 0.154182
#
# 0.0001, 1e-05, <class 'torch.optim.adadelta.Adadelta'>, 0.2, 4
# Average loss: 2.326836, Train accuracy: 0.071102, Val accuracy: 0.071341
# Average loss: 2.324390, Train accuracy: 0.071614, Val accuracy: 0.072262
# Average loss: 2.322007, Train accuracy: 0.072723, Val accuracy: 0.073678
# Average loss: 2.319830, Train accuracy: 0.074429, Val accuracy: 0.075777
# Average loss: 2.318424, Train accuracy: 0.075675, Val accuracy: 0.076238
#
# 0.0001, 1e-05, <class 'torch.optim.adam.Adam'>, 0.2, 1
# Average loss: 1.755295, Train accuracy: 0.396035, Val accuracy: 0.647852
# Average loss: 1.122823, Train accuracy: 0.654455, Val accuracy: 0.690015
# Average loss: 1.071304, Train accuracy: 0.673293, Val accuracy: 0.695577
# Average loss: 1.061454, Train accuracy: 0.676723, Val accuracy: 0.697113
# Average loss: 1.058668, Train accuracy: 0.678241, Val accuracy: 0.697352
#
# 0.0001, 1e-05, <class 'torch.optim.adam.Adam'>, 0.2, 2
# Average loss: 1.858811, Train accuracy: 0.371856, Val accuracy: 0.608760
# Average loss: 1.135161, Train accuracy: 0.653517, Val accuracy: 0.727571
# Average loss: 0.961290, Train accuracy: 0.713289, Val accuracy: 0.746835
# Average loss: 0.925986, Train accuracy: 0.726171, Val accuracy: 0.756424
# Average loss: 0.905391, Train accuracy: 0.734771, Val accuracy: 0.758898
#
# 0.0001, 1e-05, <class 'torch.optim.adam.Adam'>, 0.2, 4
# Average loss: 1.842699, Train accuracy: 0.371668, Val accuracy: 0.629219
# Average loss: 1.050656, Train accuracy: 0.676467, Val accuracy: 0.743286
# Average loss: 0.870483, Train accuracy: 0.740641, Val accuracy: 0.775944
# Average loss: 0.793827, Train accuracy: 0.766099, Val accuracy: 0.798109
# Average loss: 0.738709, Train accuracy: 0.787547, Val accuracy: 0.805361
#
# 0.0001, 1e-07, <class 'torch.optim.adadelta.Adadelta'>, 0.2, 1
# Average loss: 2.285893, Train accuracy: 0.137102, Val accuracy: 0.137631
# Average loss: 2.284778, Train accuracy: 0.137733, Val accuracy: 0.138296
# Average loss: 2.284537, Train accuracy: 0.138535, Val accuracy: 0.138365
# Average loss: 2.284544, Train accuracy: 0.139269, Val accuracy: 0.138348
# Average loss: 2.284545, Train accuracy: 0.138860, Val accuracy: 0.138348
#
# 0.0001, 1e-07, <class 'torch.optim.adadelta.Adadelta'>, 0.2, 2
# Average loss: 2.320108, Train accuracy: 0.069617, Val accuracy: 0.070709
# Average loss: 2.317686, Train accuracy: 0.071102, Val accuracy: 0.072552
# Average loss: 2.316350, Train accuracy: 0.072757, Val accuracy: 0.073150
# Average loss: 2.316073, Train accuracy: 0.072655, Val accuracy: 0.073337
# Average loss: 2.315617, Train accuracy: 0.072057, Val accuracy: 0.073457
#
# 0.0001, 1e-07, <class 'torch.optim.adadelta.Adadelta'>, 0.2, 4
# Average loss: 2.314208, Train accuracy: 0.077142, Val accuracy: 0.078098
# Average loss: 2.312581, Train accuracy: 0.078797, Val accuracy: 0.081766
# Average loss: 2.310913, Train accuracy: 0.082944, Val accuracy: 0.086868
# Average loss: 2.309435, Train accuracy: 0.087073, Val accuracy: 0.091851
# Average loss: 2.308506, Train accuracy: 0.090059, Val accuracy: 0.093438
#
# 0.0001, 1e-07, <class 'torch.optim.adam.Adam'>, 0.2, 1
# Average loss: 1.801403, Train accuracy: 0.387264, Val accuracy: 0.657458
# Average loss: 1.122905, Train accuracy: 0.657714, Val accuracy: 0.690697
# Average loss: 1.070645, Train accuracy: 0.675443, Val accuracy: 0.698495
# Average loss: 1.059885, Train accuracy: 0.677081, Val accuracy: 0.699621
# Average loss: 1.060940, Train accuracy: 0.676501, Val accuracy: 0.699928
#
# 0.0001, 1e-07, <class 'torch.optim.adam.Adam'>, 0.2, 2
# Average loss: 1.858403, Train accuracy: 0.365321, Val accuracy: 0.603607
# Average loss: 1.097027, Train accuracy: 0.666092, Val accuracy: 0.739566
# Average loss: 0.906868, Train accuracy: 0.732468, Val accuracy: 0.760366
# Average loss: 0.872149, Train accuracy: 0.743030, Val accuracy: 0.767328
# Average loss: 0.852350, Train accuracy: 0.749582, Val accuracy: 0.770365
#
# 0.0001, 1e-07, <class 'torch.optim.adam.Adam'>, 0.2, 4
# Average loss: 1.730655, Train accuracy: 0.407774, Val accuracy: 0.675375
# Average loss: 0.964028, Train accuracy: 0.707180, Val accuracy: 0.767857
# Average loss: 0.806432, Train accuracy: 0.763113, Val accuracy: 0.796744
# Average loss: 0.744014, Train accuracy: 0.785926, Val accuracy: 0.812016
# Average loss: 0.700800, Train accuracy: 0.799730, Val accuracy: 0.819114

# %%
#!g1.1
best_val_accuracy = None
best_hyperparams = None
best_run = None

for hyperparams, run_result in run_record.items():
    final_val_accuracy = run_result[2][-1]
    if best_val_accuracy is None or best_val_accuracy < final_val_accuracy:
        best_val_accuracy = final_val_accuracy
        best_hyperparams = hyperparams
        best_run = run_result

print("Best validation accuracy: %4.2f, best hyperparams: %s" % (best_val_accuracy, best_hyperparams))
# Out:
# Best validation accuracy: 0.87, best hyperparams: Hyperparams(learning_rate=1.0, anneal_epochs=2, reg=1e-07, optimizer_func=<class 'torch.optim.adadelta.Adadelta'>)

# %% [markdown]
# # Свободное упражнение - догоним и перегоним LeNet!
#
# Попробуйте найти архитектуру и настройки тренировки, чтобы выступить лучше наших бейзлайнов.
#
# Что можно и нужно попробовать:
# - BatchNormalization (для convolution layers он в PyTorch называется [batchnorm2d](https://pytorch.org/docs/stable/nn.html#batchnorm2d))
# - Изменить количество слоев и их толщину
# - Изменять количество эпох тренировки
# - Попробовать и другие агментации

# %%
#!g1.1
epoch_num = 10

best_model = nn.Sequential(
    nn.Conv2d(3, 6, 5, padding=1),
    nn.ReLU(inplace=True),
    nn.BatchNorm2d(6),
    nn.MaxPool2d(2),
    nn.Conv2d(6, 16, 5, padding=1),
    nn.ReLU(inplace=True),
    nn.BatchNorm2d(16),
    nn.MaxPool2d(2),
    nn.Conv2d(16, 120, 5, padding=1),
    nn.ReLU(inplace=True),
    Flattener(),
    nn.Linear(1920, 84),
    nn.ReLU(inplace=True),
    nn.Linear(84, 10)
)
best_model.type(torch.cuda.FloatTensor)
best_model.to(device)

optimizer = optim.Adadelta(best_model.parameters(), lr=1.0, weight_decay=1e-7)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=2, gamma=0.2)
loss_history, train_history, val_history = train_model(best_model, train_aug_loader, val_loader, loss, optimizer,
                                                       epoch_num, scheduler=scheduler)
# Out:
# Average loss: 0.610850, Train accuracy: 0.809064, Val accuracy: 0.894021
# Average loss: 0.375488, Train accuracy: 0.888595, Val accuracy: 0.919872
# Average loss: 0.253070, Train accuracy: 0.926680, Val accuracy: 0.947787
# Average loss: 0.221348, Train accuracy: 0.935774, Val accuracy: 0.953247
# Average loss: 0.194265, Train accuracy: 0.944494, Val accuracy: 0.957922
# Average loss: 0.188208, Train accuracy: 0.947258, Val accuracy: 0.959236
# Average loss: 0.180044, Train accuracy: 0.949425, Val accuracy: 0.959936
# Average loss: 0.177056, Train accuracy: 0.950534, Val accuracy: 0.960209
# Average loss: 0.177560, Train accuracy: 0.949852, Val accuracy: 0.960106
# Average loss: 0.176625, Train accuracy: 0.950073, Val accuracy: 0.960311

# %% [markdown]
# # Финальный аккорд - проверим лучшую модель на test set
#
# В качестве разнообразия - напишите код для прогона модели на test set вы.
#
# В результате вы должны натренировать модель, которая покажет более **90%** точности на test set.
# Как водится, лучший результат в группе получит дополнительные баллы!

# %%
#!g1.1
# TODO Write the code to compute accuracy on test set
test_loader = torch.utils.data.DataLoader(data_train, batch_size=batch_size, num_workers=4)
final_test_accuracy = compute_accuracy(best_model, test_loader)
print("Final test accuracy - ", final_test_accuracy)
# Out:
# Final test accuracy -  tensor(0.9529, device='cuda:0')

# %%
#!g1.1
